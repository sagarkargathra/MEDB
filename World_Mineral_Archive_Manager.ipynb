# %%
import sqlite3
import pandas as pd

# The Master Connection - Use this for the rest of the project
DB_PATH = "World_Mineral_Archive.db"

def run_query(query):
    """A helper function to quickly see results in your notebook"""
    conn = sqlite3.connect(DB_PATH)
    df = pd.read_sql(query, conn)
    conn.close()
    return df

print("✅ Connected to World_Mineral_Archive.db")
print("Ready for analysis and US data integration.")
# Out:
# ✅ Connected to World_Mineral_Archive.db
# Ready for analysis and US data integration.

# %%
def get_archive_status():
    conn = sqlite3.connect(DB_PATH)
    
    # 1. Get Table Names
    tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
    
    print("📂 --- WORLD MINERAL ARCHIVE DASHBOARD --- 📂")
    for table in tables['name']:
        if table == 'sqlite_sequence': continue
        
        # 2. Get row counts for each table
        count = conn.execute(f"SELECT COUNT(*) FROM {table}").fetchone()[0]
        print(f"🔹 Table: {table:<15} | Rows: {count:,}")
    
    conn.close()

get_archive_status()
# Out:
# 📂 --- WORLD MINERAL ARCHIVE DASHBOARD --- 📂
# 🔹 Table: BGS_Global      | Rows: 408,480

# %%
conn = sqlite3.connect(DB_PATH)
# This lists the actual column names in your BGS_Global table
columns = conn.execute("PRAGMA table_info(BGS_Global)").fetchall()
for col in columns:
    print(f"📍 Column Found: {col[1]}")
conn.close()
# Out:
# 📍 Column Found: yearbook_table_trans
# 📍 Column Found: bgs_commodity_code
# 📍 Column Found: units
# 📍 Column Found: bgs_statistic_type_trans
# 📍 Column Found: bgs_commodity_trans
# 📍 Column Found: concat_table_notes_code
# 📍 Column Found: country_trans
# 📍 Column Found: bgs_sub_commodity_trans
# 📍 Column Found: concat_table_notes_text
# 📍 Column Found: country_iso2_code
# 📍 Column Found: erml_group
# 📍 Column Found: concat_figure_notes_code
# 📍 Column Found: year
# 📍 Column Found: country_iso3_code
# 📍 Column Found: erml_commodity
# 📍 Column Found: concat_figure_notes_text
# 📍 Column Found: pole_of_inaccessibility_longitude
# 📍 Column Found: erml_sub_commodity
# 📍 Column Found: yearbook_table_id
# 📍 Column Found: pole_of_inaccessibility_latitude
# 📍 Column Found: cgi_commodity_url
# 📍 Column Found: quantity
# 📍 Column Found: year_clean
# 📍 Column Found: shape

# %%
import sqlite3
import pandas as pd

DB_PATH = "World_Mineral_Archive.db"

def inspect_lithium_raw():
    conn = sqlite3.connect(DB_PATH)
    
    # Selecting ALL columns for Lithium to see what's hidden in the sub-commodities
    query = """
    SELECT * FROM BGS_Global 
    WHERE bgs_commodity_trans LIKE '%Lithium%' 
    AND year_clean = '1983'
    ORDER BY quantity DESC
    """
    
    df = pd.read_sql(query, conn)
    conn.close()
    return df

# This will show you the wide view with all the technical columns
df_lithium = inspect_lithium_raw()
df_lithium
# Out:
#               yearbook_table_trans  bgs_commodity_code            units  \
# 0   Production of lithium minerals                 892  tonnes (metric)
# 1   Production of lithium minerals                 892  tonnes (metric)
# 2               Exports of lithium                 708  tonnes (metric)
# 3   Production of lithium minerals                 892  tonnes (metric)
# 4               Exports of lithium                 707  tonnes (metric)
# ..                             ...                 ...              ...
# 56              Exports of lithium                 709  tonnes (metric)
# 57  Production of lithium minerals                 894  tonnes (metric)
# 58  Production of lithium minerals                 892  tonnes (metric)
# 59              Exports of lithium                 707  tonnes (metric)
# 60  Production of lithium minerals                 892  tonnes (metric)
#
#    bgs_statistic_type_trans bgs_commodity_trans concat_table_notes_code  \
# 0                Production    lithium minerals                    None
# 1                Production    lithium minerals                    None
# 2                   Exports             lithium                    None
# 3                Production    lithium minerals                    None
# 4                   Exports             lithium                    None
# ..                      ...                 ...                     ...
# 56                  Exports             lithium                    None
# 57               Production    lithium minerals                    None
# 58               Production    lithium minerals                    None
# 59                  Exports             lithium                    None
# 60               Production    lithium minerals                    None
#
#          country_trans bgs_sub_commodity_trans concat_table_notes_text  \
# 0         Soviet Union                    None                    None
# 1             Zimbabwe                    None                    None
# 2             Zimbabwe        Lithium minerals                    None
# 3                China                    None                    None
# 4                  USA               Carbonate                    None
# ..                 ...                     ...                     ...
# 56  Belgium-Luxembourg                  Oxides                    None
# 57              Brazil              Lepidolite                    None
# 58              Canada                    None                    None
# 59               Chile               Carbonate                    None
# 60               Chile                    None                    None
#
#    country_iso2_code  ...    erml_commodity concat_figure_notes_text  \
# 0                 SU  ...  Lithium minerals               Estimates.
# 1                 ZW  ...  Lithium minerals                     None
# 2                 ZW  ...              None                     None
# 3                 CN  ...  Lithium minerals               Estimates.
# 4                 US  ...           Lithium                     None
# ..               ...  ...               ...                      ...
# 56              None  ...           Lithium                     None
# 57                BR  ...  Lithium minerals                     None
# 58                CA  ...  Lithium minerals                     None
# 59                CL  ...           Lithium                     None
# 60                CL  ...  Lithium minerals               Carbonate.
#
#    pole_of_inaccessibility_longitude erml_sub_commodity yearbook_table_id  \
# 0                          82.510000               None                84
# 1                          29.851884               None                84
# 2                          29.851884               None                85
# 3                         109.537431               None                84
# 4                         -97.834383          Carbonate                85
# ..                               ...                ...               ...
# 56                          5.200000             Oxides                85
# 57                        -49.028010         Lepidolite                84
# 58                       -119.677633               None                84
# 59                        -69.731919          Carbonate                85
# 60                        -69.731919               None                84
#
#    pole_of_inaccessibility_latitude  \
# 0                         55.510000
# 1                        -19.002536
# 2                        -19.002536
# 3                         32.216659
# 4                         39.139831
# ..                              ...
# 56                        50.270000
# 57                       -12.408957
# 58                        59.205384
# 59                       -26.162883
# 60                       -26.162883
#
#                                     cgi_commodity_url quantity  year_clean  \
# 0   http://resource.geosciml.org/classifier/cgi/co...  55000.0        1983
# 1   http://resource.geosciml.org/classifier/cgi/co...  19193.0        1983
# 2                                                None  16172.0        1983
# 3   http://resource.geosciml.org/classifier/cgi/co...  15000.0        1983
# 4   http://resource.geosciml.org/classifier/cgi/co...   8065.0        1983
# ..                                                ...      ...         ...
# 56  http://resource.geosciml.org/classifier/cgi/co...      2.0        1983
# 57  http://resource.geosciml.org/classifier/cgi/co...      1.0        1983
# 58  http://resource.geosciml.org/classifier/cgi/co...      0.0        1983
# 59  http://resource.geosciml.org/classifier/cgi/co...      0.0        1983
# 60  http://resource.geosciml.org/classifier/cgi/co...      0.0        1983
#
#     shape
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# ..    ...
# 56   None
# 57   None
# 58   None
# 59   None
# 60   None
#
# [61 rows x 24 columns]

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("World_Mineral_Archive.db")

# This counts how many records you have for every year in the database
query = """
SELECT year_clean, COUNT(*) as record_count 
FROM BGS_Global 
GROUP BY year_clean 
ORDER BY year_clean DESC
"""

df_years = pd.read_sql(query, conn)
print("📅 Data Coverage Timeline:")
print(df_years)

conn.close()
# Out:
# 📅 Data Coverage Timeline:
#    year_clean  record_count
# 0        2023          2973
# 1        2022          2970
# 2        2021          2971
# 3        2020          2975
# 4        2019          2947
# 5        2018          6501
# 6        2017          6527
# 7        2016          6457
# 8        2015          6349
# 9        2014          7103
# 10       2013          7023
# 11       2012          7009
# 12       2011          7384
# 13       2010          7133
# 14       2009          7135
# 15       2008          6974
# 16       2007          6877
# 17       2006          6756
# 18       2005          6649
# 19       2004          6654
# 20       2003          6460
# 21       2002         10383
# 22       2001         10488
# 23       2000         10711
# 24       1999         10667
# 25       1998         10489
# 26       1997          9964
# 27       1996          9660
# 28       1995          9423
# 29       1994          9372
# 30       1993          9005
# 31       1992          8978
# 32       1991          9173
# 33       1990          9178
# 34       1989          9111
# 35       1988          8581
# 36       1987          8599
# 37       1986          8740
# 38       1985          8652
# 39       1984          8548
# 40       1983          8412
# 41       1982          8488
# 42       1981          8425
# 43       1980          8301
# 44       1979          8200
# 45       1978          8036
# 46       1977          8039
# 47       1976          7689
# 48       1975          7461
# 49       1974          7000
# 50       1973          6417
# 51       1972          6356
# 52       1971          6073
# 53       1970          6034

# %%
import sqlite3
import pandas as pd

DB_PATH = "World_Mineral_Archive.db"

def get_clean_lithium_report():
    conn = sqlite3.connect(DB_PATH)
    
    # Applying your specific renaming structure
    query = """
    SELECT 
        year_clean AS year,
        country_trans AS country,
        country_iso2_code AS iso_code,
        bgs_statistic_type_trans AS statistic_type,
        bgs_commodity_trans AS commodity,
        bgs_sub_commodity_trans AS sub_commodity,
        quantity,
        units,
        concat_figure_notes_text AS foot_notes
    FROM BGS_Global 
    WHERE LOWER(bgs_commodity_trans) LIKE '%lithium%'
    AND LOWER(bgs_statistic_type_trans) = 'production'
    ORDER BY year ASC, country ASC
    """
    
    df = pd.read_sql(query, conn)
    conn.close()
    return df

# To view the renamed data:
df_lithium_final = get_clean_lithium_report()
display(df_lithium_final)
# Out:
#      year    country iso_code statistic_type         commodity  \
# 0    1974  Argentina       AR     Production  lithium minerals
# 1    1974     Brazil       BR     Production  lithium minerals
# 2    1974     Brazil       BR     Production  lithium minerals
# 3    1974     Brazil       BR     Production  lithium minerals
# 4    1974     Brazil       BR     Production  lithium minerals
# ..    ...        ...      ...            ...               ...
# 891  2023   Zimbabwe       ZW     Production  lithium minerals
# 892  2023   Zimbabwe       ZW     Production  lithium minerals
# 893  2023   Zimbabwe       ZW     Production  lithium minerals
# 894  2023   Zimbabwe       ZW     Production  lithium minerals
# 895  2023   Zimbabwe       ZW     Production  lithium minerals
#
#                sub_commodity  quantity            units foot_notes
# 0                       None     164.0  tonnes (metric)       None
# 1                Amblygonite     171.0  tonnes (metric)       None
# 2                 Lepidolite     460.0  tonnes (metric)       None
# 3                   Petalite    3569.0  tonnes (metric)       None
# 4                  Spodumene    1200.0  tonnes (metric)       None
# ..                       ...       ...              ...        ...
# 891   Spodumene (Li content)   12963.0  tonnes (metric)       None
# 892  Lepidolite (Li content)      10.0  tonnes (metric)       None
# 893               Lepidolite    3446.0  tonnes (metric)       None
# 894                 Petalite  301004.0  tonnes (metric)       None
# 895                Spodumene  465636.0  tonnes (metric)       None
#
# [896 rows x 9 columns]
